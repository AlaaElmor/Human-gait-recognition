# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/'  #change dir to your project folder
# Out:
# Mounted at /content/drive
# Mounted at /content/gdrive

# %%
from numpy import save, load
from pandas import read_csv
from tensorflow.keras import layers
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras import Model
from keras.layers import Conv1D, SpatialDropout1D
from keras.layers import Convolution1D, Dense,Activation
from keras.models import Input, Model
from keras.layers import LSTM, Conv1D, concatenate,GlobalMaxPooling1D,GlobalAveragePooling1D,TimeDistributed, MaxPooling1D
import tensorflow as tf
import numpy as np
import keras.backend as K
import keras.layers
from keras import optimizers
from keras.layers import Activation, Lambda
from keras.layers import Convolution1D, Dense
from keras.models import Input, Model
from typing import List, Tuple
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std
from keras.wrappers.scikit_learn import KerasClassifier

# %%
import numpy as np
x_train = np.load('gdrive/My Drive/dataset1/acc+gyr/trainX.npy')
y_train = np.load('gdrive/My Drive/dataset1/acc+gyr/trainy.npy')
x_test = np.load('gdrive/My Drive/dataset1/acc+gyr/testX.npy')
y_test = np.load('gdrive/My Drive/dataset1/acc+gyr/testy.npy')
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (33104, 128, 6) (33104, 118) (3740, 128, 6) (3740, 118)

# %%
x_train = x_train.transpose(0,2,1)
x_test = x_test.transpose(0,2,1)

# %%
# Merge inputs and targets
inputs = np.concatenate((x_train, x_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %%
embed_dim = x_train.shape[-1]   # Embedding size for each token
num_heads = 4  # Number of attention heads
ff_dim = x_train.shape[-1]  # Hidden layer size in feed forward network inside transformer

class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads,
                                             key_dim=embed_dim)
        self.ffn = keras.Sequential([
            layers.Dense(ff_dim, activation="relu"),
            layers.Dense(embed_dim),
        ])
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)  # self-attention layer
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)  # layer norm
        ffn_output = self.ffn(out1)  #feed-forward layer
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)  # layer norm

# %%
# Define per-fold score containers 
acc_per_fold = []
loss_per_fold = []
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True)
fold_no = 1
input_shape = x_train.shape[1:]
input = Input(shape=x_train.shape[1:])
for train, test in kfold.split(inputs, targets):

  model = keras.Sequential()
  model.add(layers.Input(shape= x_train.shape[1:]))
  model.add(TransformerBlock(embed_dim, num_heads, ff_dim))
  model.add(layers.GlobalAveragePooling1D())
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(ff_dim, activation='relu'))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(118, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  history = model.fit(inputs[train], targets[train], epochs=200, verbose=True, batch_size=128,callbacks=[keras.callbacks.EarlyStopping(monitor='loss', patience=5,restore_best_weights=True)])
    # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

model.summary()
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/200
# 231/231 [==============================] - 5s 13ms/step - loss: 3.2278 - accuracy: 0.2546
# Epoch 2/200
# 231/231 [==============================] - 3s 13ms/step - loss: 1.4008 - accuracy: 0.6484
# Epoch 3/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.9569 - accuracy: 0.7577
# Epoch 4/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.7634 - accuracy: 0.8038
# Epoch 5/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.6731 - accuracy: 0.8239
# Epoch 6/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.6140 - accuracy: 0.8368
# Epoch 7/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5494 - accuracy: 0.8524
# Epoch 8/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5036 - accuracy: 0.8626
# Epoch 9/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4778 - accuracy: 0.8681
# Epoch 10/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4415 - accuracy: 0.8753
# Epoch 11/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4337 - accuracy: 0.8785
# Epoch 12/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4026 - accuracy: 0.8855
# Epoch 13/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3843 - accuracy: 0.8899
# Epoch 14/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3716 - accuracy: 0.8922
# Epoch 15/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3640 - accuracy: 0.8940
# Epoch 16/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3486 - accuracy: 0.8985
# Epoch 17/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3324 - accuracy: 0.9029
# Epoch 18/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3359 - accuracy: 0.9015
# Epoch 19/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3137 - accuracy: 0.9087
# Epoch 20/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3129 - accuracy: 0.9067
# Epoch 21/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2901 - accuracy: 0.9120
# Epoch 22/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2983 - accuracy: 0.9119
# Epoch 23/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2848 - accuracy: 0.9158
# Epoch 24/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2908 - accuracy: 0.9125
# Epoch 25/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2738 - accuracy: 0.9189
# Epoch 26/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2695 - accuracy: 0.9185
# Epoch 27/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2810 - accuracy: 0.9147
# Epoch 28/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2527 - accuracy: 0.9229
# Epoch 29/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2566 - accuracy: 0.9209
# Epoch 30/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2504 - accuracy: 0.9234
# Epoch 31/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2384 - accuracy: 0.9279
# Epoch 32/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2438 - accuracy: 0.9256
# Epoch 33/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2604 - accuracy: 0.9215
# Epoch 34/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2393 - accuracy: 0.9285
# Epoch 35/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2433 - accuracy: 0.9257
# Epoch 36/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2381 - accuracy: 0.9277
# Epoch 37/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2279 - accuracy: 0.9298
# Epoch 38/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2290 - accuracy: 0.9289
# Epoch 39/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2184 - accuracy: 0.9333
# Epoch 40/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2203 - accuracy: 0.9303
# Epoch 41/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2215 - accuracy: 0.9315
# Epoch 42/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2070 - accuracy: 0.9351
# Epoch 43/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2153 - accuracy: 0.9331
# Epoch 44/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2049 - accuracy: 0.9364
# Epoch 45/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2150 - accuracy: 0.9321
# Epoch 46/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2152 - accuracy: 0.9317
# Epoch 47/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2093 - accuracy: 0.9349
# Epoch 48/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2125 - accuracy: 0.9346
# Epoch 49/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2004 - accuracy: 0.9386
# Epoch 50/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2061 - accuracy: 0.9353
# Epoch 51/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2000 - accuracy: 0.9372
# Epoch 52/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1938 - accuracy: 0.9385
# Epoch 53/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1991 - accuracy: 0.9372
# Epoch 54/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1874 - accuracy: 0.9409
# Epoch 55/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1949 - accuracy: 0.9378
# Epoch 56/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1970 - accuracy: 0.9376
# Epoch 57/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1985 - accuracy: 0.9379
# Epoch 58/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2012 - accuracy: 0.9376
# Epoch 59/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1958 - accuracy: 0.9392
# Score for fold 1: loss of 0.373963862657547; accuracy of 92.38702654838562%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/200
# 231/231 [==============================] - 5s 13ms/step - loss: 3.1889 - accuracy: 0.2610
# Epoch 2/200
# 231/231 [==============================] - 3s 13ms/step - loss: 1.4080 - accuracy: 0.6459
# Epoch 3/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.9880 - accuracy: 0.7472
# Epoch 4/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.8043 - accuracy: 0.7885
# Epoch 5/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.7031 - accuracy: 0.8120
# Epoch 6/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.6251 - accuracy: 0.8311
# Epoch 7/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5795 - accuracy: 0.8437
# Epoch 8/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5393 - accuracy: 0.8532
# Epoch 9/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5043 - accuracy: 0.8595
# Epoch 10/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4808 - accuracy: 0.8652
# Epoch 11/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4504 - accuracy: 0.8712
# Epoch 12/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4337 - accuracy: 0.8751
# Epoch 13/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4067 - accuracy: 0.8846
# Epoch 14/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3885 - accuracy: 0.8893
# Epoch 15/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3759 - accuracy: 0.8885
# Epoch 16/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3710 - accuracy: 0.8932
# Epoch 17/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3529 - accuracy: 0.8947
# Epoch 18/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3432 - accuracy: 0.8971
# Epoch 19/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3360 - accuracy: 0.9006
# Epoch 20/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3232 - accuracy: 0.9027
# Epoch 21/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3230 - accuracy: 0.9008
# Epoch 22/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3111 - accuracy: 0.9066
# Epoch 23/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3051 - accuracy: 0.9082
# Epoch 24/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2963 - accuracy: 0.9110
# Epoch 25/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2885 - accuracy: 0.9121
# Epoch 26/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2698 - accuracy: 0.9180
# Epoch 27/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2775 - accuracy: 0.9147
# Epoch 28/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2819 - accuracy: 0.9133
# Epoch 29/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2643 - accuracy: 0.9188
# Epoch 30/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2637 - accuracy: 0.9168
# Epoch 31/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2786 - accuracy: 0.9149
# Epoch 32/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2573 - accuracy: 0.9211
# Epoch 33/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2495 - accuracy: 0.9225
# Epoch 34/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2483 - accuracy: 0.9226
# Epoch 35/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2353 - accuracy: 0.9287
# Epoch 36/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2505 - accuracy: 0.9208
# Epoch 37/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2464 - accuracy: 0.9237
# Epoch 38/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2492 - accuracy: 0.9230
# Epoch 39/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2302 - accuracy: 0.9278
# Epoch 40/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2215 - accuracy: 0.9303
# Epoch 41/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2347 - accuracy: 0.9271
# Epoch 42/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2281 - accuracy: 0.9276
# Epoch 43/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2288 - accuracy: 0.9293
# Epoch 44/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2133 - accuracy: 0.9333
# Epoch 45/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2234 - accuracy: 0.9300
# Epoch 46/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2219 - accuracy: 0.9314
# Epoch 47/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2086 - accuracy: 0.9331
# Epoch 48/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2131 - accuracy: 0.9324
# Epoch 49/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2020 - accuracy: 0.9357
# Epoch 50/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2095 - accuracy: 0.9365
# Epoch 51/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2167 - accuracy: 0.9311
# Epoch 52/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2156 - accuracy: 0.9329
# Epoch 53/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1969 - accuracy: 0.9376
# Epoch 54/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2014 - accuracy: 0.9372
# Epoch 55/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2052 - accuracy: 0.9357
# Epoch 56/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2077 - accuracy: 0.9340
# Epoch 57/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2031 - accuracy: 0.9357
# Epoch 58/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1861 - accuracy: 0.9407
# Epoch 59/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1896 - accuracy: 0.9403
# Epoch 60/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1916 - accuracy: 0.9390
# Epoch 61/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2174 - accuracy: 0.9322
# Epoch 62/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1973 - accuracy: 0.9383
# Epoch 63/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1802 - accuracy: 0.9418
# Epoch 64/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1886 - accuracy: 0.9399
# Epoch 65/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1793 - accuracy: 0.9424
# Epoch 66/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1821 - accuracy: 0.9413
# Epoch 67/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1866 - accuracy: 0.9399
# Epoch 68/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1890 - accuracy: 0.9416
# Epoch 69/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1740 - accuracy: 0.9455
# Epoch 70/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1923 - accuracy: 0.9396
# Epoch 71/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1836 - accuracy: 0.9424
# Epoch 72/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1785 - accuracy: 0.9425
# Epoch 73/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1885 - accuracy: 0.9401
# Epoch 74/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1693 - accuracy: 0.9470
# Epoch 75/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2136 - accuracy: 0.9345
# Epoch 76/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1684 - accuracy: 0.9453
# Epoch 77/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1758 - accuracy: 0.9435
# Epoch 78/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1733 - accuracy: 0.9450
# Epoch 79/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1729 - accuracy: 0.9456
# Epoch 80/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1701 - accuracy: 0.9456
# Epoch 81/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1771 - accuracy: 0.9439
# Score for fold 2: loss of 0.5178440809249878; accuracy of 90.0393545627594%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/200
# 231/231 [==============================] - 5s 13ms/step - loss: 3.1921 - accuracy: 0.2610
# Epoch 2/200
# 231/231 [==============================] - 3s 14ms/step - loss: 1.4360 - accuracy: 0.6380
# Epoch 3/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.9991 - accuracy: 0.7468
# Epoch 4/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.8175 - accuracy: 0.7880
# Epoch 5/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.7055 - accuracy: 0.8176
# Epoch 6/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.6341 - accuracy: 0.8315
# Epoch 7/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5840 - accuracy: 0.8423
# Epoch 8/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5495 - accuracy: 0.8485
# Epoch 9/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5140 - accuracy: 0.8595
# Epoch 10/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4822 - accuracy: 0.8670
# Epoch 11/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4587 - accuracy: 0.8721
# Epoch 12/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4391 - accuracy: 0.8770
# Epoch 13/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4186 - accuracy: 0.8828
# Epoch 14/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3905 - accuracy: 0.8924
# Epoch 15/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3882 - accuracy: 0.8880
# Epoch 16/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3666 - accuracy: 0.8932
# Epoch 17/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3566 - accuracy: 0.8964
# Epoch 18/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3492 - accuracy: 0.8988
# Epoch 19/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3341 - accuracy: 0.9020
# Epoch 20/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3417 - accuracy: 0.9008
# Epoch 21/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3218 - accuracy: 0.9059
# Epoch 22/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3149 - accuracy: 0.9067
# Epoch 23/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3129 - accuracy: 0.9058
# Epoch 24/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2915 - accuracy: 0.9155
# Epoch 25/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2927 - accuracy: 0.9127
# Epoch 26/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2888 - accuracy: 0.9128
# Epoch 27/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2782 - accuracy: 0.9164
# Epoch 28/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2831 - accuracy: 0.9153
# Epoch 29/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2698 - accuracy: 0.9175
# Epoch 30/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2623 - accuracy: 0.9211
# Epoch 31/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2593 - accuracy: 0.9188
# Epoch 32/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2585 - accuracy: 0.9239
# Epoch 33/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2545 - accuracy: 0.9209
# Epoch 34/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2522 - accuracy: 0.9232
# Epoch 35/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2435 - accuracy: 0.9239
# Epoch 36/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2456 - accuracy: 0.9251
# Epoch 37/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2546 - accuracy: 0.9213
# Epoch 38/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2331 - accuracy: 0.9265
# Epoch 39/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2353 - accuracy: 0.9271
# Epoch 40/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2328 - accuracy: 0.9282
# Epoch 41/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2323 - accuracy: 0.9285
# Epoch 42/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2298 - accuracy: 0.9280
# Epoch 43/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2261 - accuracy: 0.9294
# Epoch 44/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2070 - accuracy: 0.9375
# Epoch 45/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2158 - accuracy: 0.9333
# Epoch 46/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2124 - accuracy: 0.9349
# Epoch 47/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2058 - accuracy: 0.9366
# Epoch 48/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2258 - accuracy: 0.9301
# Epoch 49/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2142 - accuracy: 0.9337
# Epoch 50/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2088 - accuracy: 0.9352
# Epoch 51/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1962 - accuracy: 0.9392
# Epoch 52/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2214 - accuracy: 0.9328
# Epoch 53/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2003 - accuracy: 0.9380
# Epoch 54/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2151 - accuracy: 0.9344
# Epoch 55/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2069 - accuracy: 0.9350
# Epoch 56/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1981 - accuracy: 0.9379
# Score for fold 3: loss of 0.4530068337917328; accuracy of 90.01221060752869%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/200
# 231/231 [==============================] - 5s 14ms/step - loss: 3.1590 - accuracy: 0.2668
# Epoch 2/200
# 231/231 [==============================] - 3s 13ms/step - loss: 1.2939 - accuracy: 0.6763
# Epoch 3/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.9061 - accuracy: 0.7706
# Epoch 4/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.7668 - accuracy: 0.8027
# Epoch 5/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.6820 - accuracy: 0.8201
# Epoch 6/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.6053 - accuracy: 0.8399
# Epoch 7/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.5627 - accuracy: 0.8480
# Epoch 8/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.5264 - accuracy: 0.8559
# Epoch 9/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4833 - accuracy: 0.8673
# Epoch 10/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4589 - accuracy: 0.8711
# Epoch 11/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4602 - accuracy: 0.8721
# Epoch 12/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.4258 - accuracy: 0.8814
# Epoch 13/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.4103 - accuracy: 0.8845
# Epoch 14/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4098 - accuracy: 0.8835
# Epoch 15/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3918 - accuracy: 0.8877
# Epoch 16/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.3733 - accuracy: 0.8923
# Epoch 17/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3662 - accuracy: 0.8939
# Epoch 18/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3506 - accuracy: 0.8973
# Epoch 19/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3408 - accuracy: 0.9001
# Epoch 20/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3357 - accuracy: 0.9026
# Epoch 21/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3262 - accuracy: 0.9045
# Epoch 22/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.3257 - accuracy: 0.9014
# Epoch 23/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3187 - accuracy: 0.9051
# Epoch 24/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3105 - accuracy: 0.9072
# Epoch 25/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2946 - accuracy: 0.9119
# Epoch 26/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2958 - accuracy: 0.9107
# Epoch 27/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2947 - accuracy: 0.9100
# Epoch 28/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2916 - accuracy: 0.9116
# Epoch 29/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2874 - accuracy: 0.9125
# Epoch 30/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2702 - accuracy: 0.9194
# Epoch 31/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2709 - accuracy: 0.9173
# Epoch 32/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2774 - accuracy: 0.9146
# Epoch 33/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2666 - accuracy: 0.9188
# Epoch 34/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2534 - accuracy: 0.9231
# Epoch 35/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2649 - accuracy: 0.9199
# Epoch 36/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2561 - accuracy: 0.9222
# Epoch 37/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2522 - accuracy: 0.9222
# Epoch 38/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2545 - accuracy: 0.9229
# Epoch 39/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2534 - accuracy: 0.9223
# Epoch 40/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2454 - accuracy: 0.9253
# Epoch 41/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2428 - accuracy: 0.9263
# Epoch 42/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2391 - accuracy: 0.9246
# Epoch 43/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2392 - accuracy: 0.9269
# Epoch 44/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2370 - accuracy: 0.9275
# Epoch 45/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2362 - accuracy: 0.9275
# Epoch 46/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2389 - accuracy: 0.9260
# Epoch 47/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2208 - accuracy: 0.9315
# Epoch 48/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2359 - accuracy: 0.9262
# Epoch 49/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2419 - accuracy: 0.9257
# Epoch 50/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2292 - accuracy: 0.9276
# Epoch 51/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2161 - accuracy: 0.9321
# Epoch 52/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2429 - accuracy: 0.9261
# Epoch 53/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2165 - accuracy: 0.9318
# Epoch 54/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2150 - accuracy: 0.9323
# Epoch 55/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2197 - accuracy: 0.9310
# Epoch 56/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2134 - accuracy: 0.9335
# Epoch 57/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1999 - accuracy: 0.9360
# Epoch 58/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2292 - accuracy: 0.9279
# Epoch 59/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2159 - accuracy: 0.9327
# Epoch 60/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2042 - accuracy: 0.9367
# Epoch 61/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2064 - accuracy: 0.9366
# Epoch 62/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2035 - accuracy: 0.9357
# Score for fold 4: loss of 0.44340208172798157; accuracy of 90.20220041275024%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/200
# 231/231 [==============================] - 5s 14ms/step - loss: 3.2818 - accuracy: 0.2320
# Epoch 2/200
# 231/231 [==============================] - 3s 14ms/step - loss: 1.4999 - accuracy: 0.6180
# Epoch 3/200
# 231/231 [==============================] - 3s 14ms/step - loss: 1.0205 - accuracy: 0.7366
# Epoch 4/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.8192 - accuracy: 0.7868
# Epoch 5/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.7169 - accuracy: 0.8091
# Epoch 6/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.6394 - accuracy: 0.8273
# Epoch 7/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.5911 - accuracy: 0.8399
# Epoch 8/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.5409 - accuracy: 0.8517
# Epoch 9/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.5032 - accuracy: 0.8611
# Epoch 10/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4805 - accuracy: 0.8648
# Epoch 11/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.4447 - accuracy: 0.8749
# Epoch 12/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.4358 - accuracy: 0.8758
# Epoch 13/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4243 - accuracy: 0.8796
# Epoch 14/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.4018 - accuracy: 0.8844
# Epoch 15/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3972 - accuracy: 0.8841
# Epoch 16/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3660 - accuracy: 0.8944
# Epoch 17/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3519 - accuracy: 0.8973
# Epoch 18/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3483 - accuracy: 0.8976
# Epoch 19/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3394 - accuracy: 0.8986
# Epoch 20/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.3280 - accuracy: 0.9045
# Epoch 21/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.3336 - accuracy: 0.9006
# Epoch 22/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3117 - accuracy: 0.9064
# Epoch 23/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.3029 - accuracy: 0.9110
# Epoch 24/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3030 - accuracy: 0.9092
# Epoch 25/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.3146 - accuracy: 0.9053
# Epoch 26/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2812 - accuracy: 0.9153
# Epoch 27/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2818 - accuracy: 0.9161
# Epoch 28/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2771 - accuracy: 0.9160
# Epoch 29/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2778 - accuracy: 0.9160
# Epoch 30/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2686 - accuracy: 0.9183
# Epoch 31/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2743 - accuracy: 0.9150
# Epoch 32/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2457 - accuracy: 0.9227
# Epoch 33/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2524 - accuracy: 0.9231
# Epoch 34/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2520 - accuracy: 0.9226
# Epoch 35/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2505 - accuracy: 0.9239
# Epoch 36/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2511 - accuracy: 0.9229
# Epoch 37/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2449 - accuracy: 0.9244
# Epoch 38/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2413 - accuracy: 0.9263
# Epoch 39/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2411 - accuracy: 0.9261
# Epoch 40/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2378 - accuracy: 0.9269
# Epoch 41/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2334 - accuracy: 0.9281
# Epoch 42/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2211 - accuracy: 0.9315
# Epoch 43/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2167 - accuracy: 0.9325
# Epoch 44/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2309 - accuracy: 0.9281
# Epoch 45/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2351 - accuracy: 0.9295
# Epoch 46/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2088 - accuracy: 0.9341
# Epoch 47/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2132 - accuracy: 0.9321
# Epoch 48/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2100 - accuracy: 0.9340
# Epoch 49/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2203 - accuracy: 0.9311
# Epoch 50/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2150 - accuracy: 0.9340
# Epoch 51/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2087 - accuracy: 0.9354
# Epoch 52/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.2087 - accuracy: 0.9340
# Epoch 53/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2111 - accuracy: 0.9347
# Epoch 54/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2027 - accuracy: 0.9368
# Epoch 55/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1945 - accuracy: 0.9404
# Epoch 56/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2002 - accuracy: 0.9364
# Epoch 57/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2040 - accuracy: 0.9357
# Epoch 58/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.2220 - accuracy: 0.9298
# Epoch 59/200
# 231/231 [==============================] - 3s 13ms/step - loss: 0.1907 - accuracy: 0.9408
# Epoch 60/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1922 - accuracy: 0.9388
# Epoch 61/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1856 - accuracy: 0.9416
# Epoch 62/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1893 - accuracy: 0.9394
# Epoch 63/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1929 - accuracy: 0.9405
# Epoch 64/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1874 - accuracy: 0.9402
# Epoch 65/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1955 - accuracy: 0.9383
# Epoch 66/200
# 231/231 [==============================] - 3s 14ms/step - loss: 0.1908 - accuracy: 0.9399
# Score for fold 5: loss of 0.4411257803440094; accuracy of 91.11020565032959%
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  transformer_block_9 (Transf  (None, 6, 128)           297344
#  ormerBlock)
#
#  global_average_pooling1d_9   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dropout_38 (Dropout)        (None, 128)               0
#
#  dense_38 (Dense)            (None, 128)               16512
#
#  dropout_39 (Dropout)        (None, 128)               0
#
#  dense_39 (Dense)            (None, 118)               15222
#
# =================================================================
# Total params: 329,078
# Trainable params: 329,078
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Average scores 
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.373963862657547 - Accuracy: 92.38702654838562%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.5178440809249878 - Accuracy: 90.0393545627594%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.4530068337917328 - Accuracy: 90.01221060752869%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.44340208172798157 - Accuracy: 90.20220041275024%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.4411257803440094 - Accuracy: 91.11020565032959%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 90.75019955635071 (+- 0.9120349055206266)
# > Loss: 0.4458685278892517
# ------------------------------------------------------------------------
