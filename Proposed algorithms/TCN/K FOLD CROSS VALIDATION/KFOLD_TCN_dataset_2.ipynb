# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import drive

drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/'  #change dir to your project folder
# Out:
# Mounted at /content/drive
# Mounted at /content/gdrive

# %%
from numpy import save, load
from pandas import read_csv
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras import Model
from keras.layers import Conv1D, SpatialDropout1D
from keras.layers import Convolution1D, Dense,Activation
from keras.models import Input, Model
from keras.layers import LSTM, Conv1D, concatenate,GlobalMaxPooling1D,GlobalAveragePooling1D,TimeDistributed, MaxPooling1D
import tensorflow as tf
import numpy as np
import keras.backend as K
import keras.layers
from keras import optimizers
from keras.layers import Activation, Lambda
from keras.layers import Convolution1D, Dense
from keras.models import Input, Model
from typing import List, Tuple
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std
from keras.wrappers.scikit_learn import KerasClassifier

# %%
import numpy as np
x_train = np.load('gdrive/My Drive/dataset/dataset2/trainX.npy')
y_train = np.load('gdrive/My Drive/dataset/dataset2/trainy.npy')
x_test = np.load('gdrive/My Drive/dataset/dataset2/testX.npy')
y_test = np.load('gdrive/My Drive/dataset/dataset2/testy.npy')
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (44339, 128, 6) (44339, 20) (4936, 128, 6) (4936, 20)

# %%
# Merge inputs and targets
inputs = np.concatenate((x_train, x_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %%
# prepare the cross-validation procedure
#cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
#from sklearn.model_selection import train_test_split
#x_train, x_validation, y_train, y_validation = train_test_split(x_train, y_train, test_size=0.20, random_state=42)

# %%
def channel_normalization(x):
    max_values = K.max(K.abs(x), 2, keepdims=True) + 1e-5
    out = x / max_values
    return out

def residual_block(x, s, i, activation, nb_filters, kernel_size, padding, dropout_rate=0, name=''):
    original_x = x
    conv = Conv1D(filters=nb_filters, kernel_size=kernel_size,
                  dilation_rate=i, padding=padding,
                  name=name + '_dilated_conv_%d_tanh_s%d' % (i, s))(x)
    if activation == 'norm_relu':
        x = Activation('relu')(conv)
        x = Lambda(channel_normalization)(x)
    else:
        x = Activation(activation)(conv)

    x = SpatialDropout1D(dropout_rate, name=name + '_spatial_dropout1d_%d_s%d_%f' % (i, s, dropout_rate))(x)

    # 1x1 conv.
    x = Convolution1D(nb_filters, 1, padding='same')(x)
    res_x = keras.layers.add([original_x, x])
    return res_x, x

# %%
class TCN:

    def __init__(self,
                 nb_filters=64,
                 kernel_size=2,
                 nb_stacks=1,
                 dilations=None,
                 activation='norm_relu',
                 padding='causal',
                 use_skip_connections=True,
                 dropout_rate=0.0,
                 return_sequences=True,
                 name='tcn'):
        self.name = name
        self.return_sequences = return_sequences
        self.dropout_rate = dropout_rate
        self.use_skip_connections = use_skip_connections
        self.activation = activation
        self.dilations = dilations
        self.nb_stacks = nb_stacks
        self.kernel_size = kernel_size
        self.nb_filters = nb_filters
        self.padding = padding
        
        if padding != 'causal' and padding != 'same':
            raise ValueError("Only 'causal' or 'same' paddings are compatible for this layer.")

        if not isinstance(nb_filters, int):
            print('An interface change occurred after the version 2.1.2.')
            print('Before: tcn.TCN(i, return_sequences=False, ...)')
            print('Now should be: tcn.TCN(return_sequences=False, ...)(i)')
            print('Second solution is to pip install keras-tcn==2.1.2 to downgrade.')
            raise Exception()

    def __call__(self, inputs):
        if self.dilations is None:
            self.dilations = [1, 2, 4, 8, 16, 32]
        x = inputs
        x = Convolution1D(self.nb_filters, 1, padding=self.padding, name=self.name + '_initial_conv')(x)
        skip_connections = []
        for s in range(self.nb_stacks):
            for i in self.dilations:
                x, skip_out = residual_block(x, s, i, self.activation, self.nb_filters,
                                             self.kernel_size, self.padding, self.dropout_rate, name=self.name)
                skip_connections.append(skip_out)
        if self.use_skip_connections:
            x = keras.layers.add(skip_connections)
        x = Activation('relu')(x)

        if not self.return_sequences:
            output_slice_index = -1
            x = Lambda(lambda tt: tt[:, output_slice_index, :])(x)
        return x

# %%
# Define per-fold score containers 
acc_per_fold = []
loss_per_fold = []
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True)
fold_no = 1
input_shape = x_train.shape[1:]
input = Input(shape=x_train.shape[1:])
for train, test in kfold.split(inputs, targets):

  x = SpatialDropout1D(0.2)(input)
  x = TCN(128,dilations = [1, 2, 4, 8, 16],kernel_size = 3, return_sequences=True, name = 'tnc1')(x)
  x = TCN(128,dilations = [1, 2, 4, 8, 16],kernel_size = 3, return_sequences=True, name = 'tnc2')(x)
  max_pool = GlobalMaxPooling1D()(x)
  x = Dense(128, activation="relu")(max_pool)
  x = Dropout(0.2)(x)
  output = Dense(20, activation="softmax")(x)    
  model = Model(inputs=input, outputs=output)
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  history = model.fit(inputs[train], targets[train], epochs=200, verbose=True, batch_size=128,callbacks=[keras.callbacks.EarlyStopping(monitor='loss', patience=5,restore_best_weights=True)])
    # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

model.summary()
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/200
# 308/308 [==============================] - 51s 147ms/step - loss: 0.7355 - accuracy: 0.7906
# Epoch 2/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1798 - accuracy: 0.9503
# Epoch 3/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1201 - accuracy: 0.9659
# Epoch 4/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0934 - accuracy: 0.9734
# Epoch 5/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0795 - accuracy: 0.9771
# Epoch 6/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0735 - accuracy: 0.9787
# Epoch 7/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0624 - accuracy: 0.9820
# Epoch 8/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0584 - accuracy: 0.9835
# Epoch 9/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0577 - accuracy: 0.9834
# Epoch 10/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0510 - accuracy: 0.9847
# Epoch 11/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0444 - accuracy: 0.9870
# Epoch 12/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0487 - accuracy: 0.9856
# Epoch 13/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0480 - accuracy: 0.9853
# Epoch 14/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0418 - accuracy: 0.9872
# Epoch 15/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0406 - accuracy: 0.9877
# Epoch 16/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0394 - accuracy: 0.9883
# Epoch 17/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0351 - accuracy: 0.9895
# Epoch 18/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0375 - accuracy: 0.9884
# Epoch 19/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0378 - accuracy: 0.9886
# Epoch 20/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0329 - accuracy: 0.9901
# Epoch 21/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0323 - accuracy: 0.9900
# Epoch 22/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0348 - accuracy: 0.9892
# Epoch 23/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0339 - accuracy: 0.9896
# Epoch 24/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0306 - accuracy: 0.9904
# Epoch 25/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0314 - accuracy: 0.9906
# Epoch 26/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0296 - accuracy: 0.9909
# Epoch 27/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0278 - accuracy: 0.9914
# Epoch 28/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0301 - accuracy: 0.9914
# Epoch 29/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0243 - accuracy: 0.9923
# Epoch 30/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0277 - accuracy: 0.9913
# Epoch 31/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0250 - accuracy: 0.9922
# Epoch 32/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0257 - accuracy: 0.9921
# Epoch 33/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0254 - accuracy: 0.9917
# Epoch 34/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0237 - accuracy: 0.9928
# Epoch 35/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0287 - accuracy: 0.9913
# Epoch 36/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0266 - accuracy: 0.9916
# Epoch 37/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0225 - accuracy: 0.9926
# Epoch 38/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0217 - accuracy: 0.9936
# Epoch 39/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0229 - accuracy: 0.9929
# Epoch 40/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0248 - accuracy: 0.9925
# Epoch 41/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0204 - accuracy: 0.9940
# Epoch 42/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0227 - accuracy: 0.9930
# Epoch 43/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0181 - accuracy: 0.9943
# Epoch 44/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0243 - accuracy: 0.9927
# Epoch 45/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0194 - accuracy: 0.9940
# Epoch 46/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0226 - accuracy: 0.9929
# Epoch 47/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0206 - accuracy: 0.9935
# Epoch 48/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0193 - accuracy: 0.9939
# Score for fold 1: loss of 0.03460532799363136; accuracy of 99.12734627723694%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/200
# 308/308 [==============================] - 49s 147ms/step - loss: 0.7137 - accuracy: 0.7977
# Epoch 2/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1822 - accuracy: 0.9500
# Epoch 3/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1214 - accuracy: 0.9674
# Epoch 4/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1000 - accuracy: 0.9721
# Epoch 5/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0828 - accuracy: 0.9757
# Epoch 6/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0783 - accuracy: 0.9781
# Epoch 7/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0650 - accuracy: 0.9815
# Epoch 8/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0618 - accuracy: 0.9818
# Epoch 9/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0587 - accuracy: 0.9836
# Epoch 10/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0564 - accuracy: 0.9842
# Epoch 11/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0480 - accuracy: 0.9859
# Epoch 12/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0519 - accuracy: 0.9849
# Epoch 13/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0464 - accuracy: 0.9860
# Epoch 14/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0449 - accuracy: 0.9868
# Epoch 15/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0435 - accuracy: 0.9867
# Epoch 16/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0465 - accuracy: 0.9856
# Epoch 17/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0378 - accuracy: 0.9886
# Epoch 18/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0394 - accuracy: 0.9882
# Epoch 19/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0334 - accuracy: 0.9900
# Epoch 20/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0324 - accuracy: 0.9902
# Epoch 21/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0391 - accuracy: 0.9879
# Epoch 22/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0330 - accuracy: 0.9898
# Epoch 23/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0313 - accuracy: 0.9902
# Epoch 24/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0321 - accuracy: 0.9901
# Epoch 25/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0301 - accuracy: 0.9909
# Epoch 26/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0309 - accuracy: 0.9909
# Epoch 27/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0306 - accuracy: 0.9905
# Epoch 28/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0296 - accuracy: 0.9909
# Epoch 29/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0310 - accuracy: 0.9910
# Epoch 30/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0233 - accuracy: 0.9928
# Epoch 31/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0269 - accuracy: 0.9919
# Epoch 32/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0275 - accuracy: 0.9916
# Epoch 33/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0271 - accuracy: 0.9913
# Epoch 34/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0255 - accuracy: 0.9923
# Epoch 35/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0226 - accuracy: 0.9926
# Epoch 36/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0245 - accuracy: 0.9924
# Epoch 37/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0242 - accuracy: 0.9928
# Epoch 38/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0239 - accuracy: 0.9928
# Epoch 39/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0222 - accuracy: 0.9933
# Epoch 40/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0229 - accuracy: 0.9927
# Epoch 41/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0222 - accuracy: 0.9930
# Epoch 42/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0210 - accuracy: 0.9938
# Epoch 43/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0216 - accuracy: 0.9932
# Epoch 44/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0206 - accuracy: 0.9936
# Epoch 45/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0219 - accuracy: 0.9935
# Epoch 46/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0195 - accuracy: 0.9940
# Epoch 47/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0229 - accuracy: 0.9926
# Epoch 48/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0210 - accuracy: 0.9938
# Epoch 49/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0195 - accuracy: 0.9942
# Epoch 50/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0179 - accuracy: 0.9944
# Epoch 51/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0176 - accuracy: 0.9945
# Epoch 52/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0189 - accuracy: 0.9944
# Epoch 53/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0159 - accuracy: 0.9951
# Epoch 54/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0187 - accuracy: 0.9943
# Epoch 55/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0215 - accuracy: 0.9936
# Epoch 56/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0210 - accuracy: 0.9939
# Epoch 57/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0175 - accuracy: 0.9944
# Epoch 58/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0180 - accuracy: 0.9942
# Score for fold 2: loss of 0.027990803122520447; accuracy of 99.28970336914062%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/200
# 308/308 [==============================] - 49s 147ms/step - loss: 0.8054 - accuracy: 0.7671
# Epoch 2/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1921 - accuracy: 0.9461
# Epoch 3/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1239 - accuracy: 0.9645
# Epoch 4/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0975 - accuracy: 0.9726
# Epoch 5/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0834 - accuracy: 0.9762
# Epoch 6/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0709 - accuracy: 0.9797
# Epoch 7/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0688 - accuracy: 0.9797
# Epoch 8/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0600 - accuracy: 0.9826
# Epoch 9/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0572 - accuracy: 0.9828
# Epoch 10/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0531 - accuracy: 0.9845
# Epoch 11/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0555 - accuracy: 0.9832
# Epoch 12/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0454 - accuracy: 0.9861
# Epoch 13/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0458 - accuracy: 0.9866
# Epoch 14/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0451 - accuracy: 0.9870
# Epoch 15/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0424 - accuracy: 0.9868
# Epoch 16/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0427 - accuracy: 0.9871
# Epoch 17/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0385 - accuracy: 0.9877
# Epoch 18/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0389 - accuracy: 0.9882
# Epoch 19/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0367 - accuracy: 0.9887
# Epoch 20/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0336 - accuracy: 0.9898
# Epoch 21/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0303 - accuracy: 0.9912
# Epoch 22/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0307 - accuracy: 0.9907
# Epoch 23/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0331 - accuracy: 0.9899
# Epoch 24/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0305 - accuracy: 0.9912
# Epoch 25/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0311 - accuracy: 0.9906
# Epoch 26/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0321 - accuracy: 0.9900
# Score for fold 3: loss of 0.026369981467723846; accuracy of 99.22881722450256%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/200
# 308/308 [==============================] - 49s 148ms/step - loss: 0.7194 - accuracy: 0.7951
# Epoch 2/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1787 - accuracy: 0.9508
# Epoch 3/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.1146 - accuracy: 0.9678
# Epoch 4/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0965 - accuracy: 0.9733
# Epoch 5/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0805 - accuracy: 0.9771
# Epoch 6/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0757 - accuracy: 0.9782
# Epoch 7/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0707 - accuracy: 0.9789
# Epoch 8/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0622 - accuracy: 0.9819
# Epoch 9/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0550 - accuracy: 0.9843
# Epoch 10/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0527 - accuracy: 0.9850
# Epoch 11/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0495 - accuracy: 0.9854
# Epoch 12/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0472 - accuracy: 0.9858
# Epoch 13/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0446 - accuracy: 0.9870
# Epoch 14/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0441 - accuracy: 0.9864
# Epoch 15/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0411 - accuracy: 0.9882
# Epoch 16/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0417 - accuracy: 0.9872
# Epoch 17/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0415 - accuracy: 0.9876
# Epoch 18/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0376 - accuracy: 0.9882
# Epoch 19/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0356 - accuracy: 0.9895
# Epoch 20/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0358 - accuracy: 0.9894
# Epoch 21/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0333 - accuracy: 0.9900
# Epoch 22/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0338 - accuracy: 0.9897
# Epoch 23/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0315 - accuracy: 0.9903
# Epoch 24/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0305 - accuracy: 0.9906
# Epoch 25/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0296 - accuracy: 0.9905
# Epoch 26/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0307 - accuracy: 0.9905
# Epoch 27/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0303 - accuracy: 0.9908
# Epoch 28/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0287 - accuracy: 0.9911
# Epoch 29/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0319 - accuracy: 0.9900
# Epoch 30/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0293 - accuracy: 0.9914
# Epoch 31/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0291 - accuracy: 0.9915
# Epoch 32/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0258 - accuracy: 0.9923
# Epoch 33/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0251 - accuracy: 0.9922
# Epoch 34/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0269 - accuracy: 0.9918
# Epoch 35/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0247 - accuracy: 0.9923
# Epoch 36/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0230 - accuracy: 0.9926
# Epoch 37/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0275 - accuracy: 0.9919
# Epoch 38/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0212 - accuracy: 0.9933
# Epoch 39/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0249 - accuracy: 0.9923
# Epoch 40/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0226 - accuracy: 0.9930
# Epoch 41/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0215 - accuracy: 0.9939
# Epoch 42/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0208 - accuracy: 0.9936
# Epoch 43/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0245 - accuracy: 0.9924
# Epoch 44/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0199 - accuracy: 0.9935
# Epoch 45/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0220 - accuracy: 0.9931
# Epoch 46/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0228 - accuracy: 0.9931
# Epoch 47/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0182 - accuracy: 0.9942
# Epoch 48/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0213 - accuracy: 0.9940
# Epoch 49/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0217 - accuracy: 0.9933
# Epoch 50/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0177 - accuracy: 0.9940
# Epoch 51/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0203 - accuracy: 0.9935
# Epoch 52/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0193 - accuracy: 0.9941
# Epoch 53/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0217 - accuracy: 0.9936
# Epoch 54/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0191 - accuracy: 0.9938
# Epoch 55/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0172 - accuracy: 0.9950
# Epoch 56/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0172 - accuracy: 0.9945
# Epoch 57/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0165 - accuracy: 0.9946
# Epoch 58/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0168 - accuracy: 0.9950
# Epoch 59/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0212 - accuracy: 0.9934
# Epoch 60/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0165 - accuracy: 0.9952
# Epoch 61/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0183 - accuracy: 0.9942
# Epoch 62/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0206 - accuracy: 0.9937
# Epoch 63/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0155 - accuracy: 0.9949
# Epoch 64/200
# 308/308 [==============================] - 45s 148ms/step - loss: 0.0146 - accuracy: 0.9955
# Epoch 65/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0189 - accuracy: 0.9941
# Epoch 66/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0179 - accuracy: 0.9948
# Epoch 67/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0188 - accuracy: 0.9946
# Epoch 68/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0156 - accuracy: 0.9951
# Epoch 69/200
# 308/308 [==============================] - 45s 147ms/step - loss: 0.0149 - accuracy: 0.9954
# Score for fold 4: loss of 0.030791712924838066; accuracy of 99.21867251396179%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/200
# 308/308 [==============================] - 49s 148ms/step - loss: 0.7053 - accuracy: 0.7974
# Epoch 2/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.1686 - accuracy: 0.9534
# Epoch 3/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.1185 - accuracy: 0.9669
# Epoch 4/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0946 - accuracy: 0.9735
# Epoch 5/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0804 - accuracy: 0.9763
# Epoch 6/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0691 - accuracy: 0.9802
# Epoch 7/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0663 - accuracy: 0.9803
# Epoch 8/200
# 308/308 [==============================] - 46s 148ms/step - loss: 0.0590 - accuracy: 0.9834
# Epoch 9/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0605 - accuracy: 0.9821
# Epoch 10/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0498 - accuracy: 0.9857
# Epoch 11/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0515 - accuracy: 0.9849
# Epoch 12/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0448 - accuracy: 0.9867
# Epoch 13/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0445 - accuracy: 0.9863
# Epoch 14/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0420 - accuracy: 0.9867
# Epoch 15/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0375 - accuracy: 0.9889
# Epoch 16/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0446 - accuracy: 0.9865
# Epoch 17/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0393 - accuracy: 0.9882
# Epoch 18/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0363 - accuracy: 0.9895
# Epoch 19/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0362 - accuracy: 0.9888
# Epoch 20/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0341 - accuracy: 0.9898
# Epoch 21/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0322 - accuracy: 0.9903
# Epoch 22/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0356 - accuracy: 0.9887
# Epoch 23/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0310 - accuracy: 0.9904
# Epoch 24/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0347 - accuracy: 0.9900
# Epoch 25/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0317 - accuracy: 0.9903
# Epoch 26/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0287 - accuracy: 0.9916
# Epoch 27/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0255 - accuracy: 0.9919
# Epoch 28/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0274 - accuracy: 0.9919
# Epoch 29/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0271 - accuracy: 0.9920
# Epoch 30/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0274 - accuracy: 0.9912
# Epoch 31/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0278 - accuracy: 0.9914
# Epoch 32/200
# 308/308 [==============================] - 46s 149ms/step - loss: 0.0269 - accuracy: 0.9916
# Score for fold 5: loss of 0.04186524450778961; accuracy of 98.99543523788452%
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 6)]     0           []
#
#  spatial_dropout1d_7 (SpatialDr  (None, 128, 6)      0           ['input_4[0][0]']
#  opout1D)
#
#  tnc1_initial_conv (Conv1D)     (None, 128, 128)     896         ['spatial_dropout1d_7[0][0]']
#
#  tnc1_dilated_conv_1_tanh_s0 (C  (None, 128, 128)    49280       ['tnc1_initial_conv[0][0]']
#  onv1D)
#
#  activation_84 (Activation)     (None, 128, 128)     0           ['tnc1_dilated_conv_1_tanh_s0[0][
#                                                                  0]']
#
#  lambda_70 (Lambda)             (None, 128, 128)     0           ['activation_84[0][0]']
#
#  tnc1_spatial_dropout1d_1_s0_0.  (None, 128, 128)    0           ['lambda_70[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_70 (Conv1D)             (None, 128, 128)     16512       ['tnc1_spatial_dropout1d_1_s0_0.0
#                                                                  00000[0][0]']
#
#  add_84 (Add)                   (None, 128, 128)     0           ['tnc1_initial_conv[0][0]',
#                                                                   'conv1d_70[0][0]']
#
#  tnc1_dilated_conv_2_tanh_s0 (C  (None, 128, 128)    49280       ['add_84[0][0]']
#  onv1D)
#
#  activation_85 (Activation)     (None, 128, 128)     0           ['tnc1_dilated_conv_2_tanh_s0[0][
#                                                                  0]']
#
#  lambda_71 (Lambda)             (None, 128, 128)     0           ['activation_85[0][0]']
#
#  tnc1_spatial_dropout1d_2_s0_0.  (None, 128, 128)    0           ['lambda_71[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_71 (Conv1D)             (None, 128, 128)     16512       ['tnc1_spatial_dropout1d_2_s0_0.0
#                                                                  00000[0][0]']
#
#  add_85 (Add)                   (None, 128, 128)     0           ['add_84[0][0]',
#                                                                   'conv1d_71[0][0]']
#
#  tnc1_dilated_conv_4_tanh_s0 (C  (None, 128, 128)    49280       ['add_85[0][0]']
#  onv1D)
#
#  activation_86 (Activation)     (None, 128, 128)     0           ['tnc1_dilated_conv_4_tanh_s0[0][
#                                                                  0]']
#
#  lambda_72 (Lambda)             (None, 128, 128)     0           ['activation_86[0][0]']
#
#  tnc1_spatial_dropout1d_4_s0_0.  (None, 128, 128)    0           ['lambda_72[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_72 (Conv1D)             (None, 128, 128)     16512       ['tnc1_spatial_dropout1d_4_s0_0.0
#                                                                  00000[0][0]']
#
#  add_86 (Add)                   (None, 128, 128)     0           ['add_85[0][0]',
#                                                                   'conv1d_72[0][0]']
#
#  tnc1_dilated_conv_8_tanh_s0 (C  (None, 128, 128)    49280       ['add_86[0][0]']
#  onv1D)
#
#  activation_87 (Activation)     (None, 128, 128)     0           ['tnc1_dilated_conv_8_tanh_s0[0][
#                                                                  0]']
#
#  lambda_73 (Lambda)             (None, 128, 128)     0           ['activation_87[0][0]']
#
#  tnc1_spatial_dropout1d_8_s0_0.  (None, 128, 128)    0           ['lambda_73[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_73 (Conv1D)             (None, 128, 128)     16512       ['tnc1_spatial_dropout1d_8_s0_0.0
#                                                                  00000[0][0]']
#
#  add_87 (Add)                   (None, 128, 128)     0           ['add_86[0][0]',
#                                                                   'conv1d_73[0][0]']
#
#  tnc1_dilated_conv_16_tanh_s0 (  (None, 128, 128)    49280       ['add_87[0][0]']
#  Conv1D)
#
#  activation_88 (Activation)     (None, 128, 128)     0           ['tnc1_dilated_conv_16_tanh_s0[0]
#                                                                  [0]']
#
#  lambda_74 (Lambda)             (None, 128, 128)     0           ['activation_88[0][0]']
#
#  tnc1_spatial_dropout1d_16_s0_0  (None, 128, 128)    0           ['lambda_74[0][0]']
#  .000000 (SpatialDropout1D)
#
#  conv1d_74 (Conv1D)             (None, 128, 128)     16512       ['tnc1_spatial_dropout1d_16_s0_0.
#                                                                  000000[0][0]']
#
#  add_89 (Add)                   (None, 128, 128)     0           ['conv1d_70[0][0]',
#                                                                   'conv1d_71[0][0]',
#                                                                   'conv1d_72[0][0]',
#                                                                   'conv1d_73[0][0]',
#                                                                   'conv1d_74[0][0]']
#
#  activation_89 (Activation)     (None, 128, 128)     0           ['add_89[0][0]']
#
#  tnc2_initial_conv (Conv1D)     (None, 128, 128)     16512       ['activation_89[0][0]']
#
#  tnc2_dilated_conv_1_tanh_s0 (C  (None, 128, 128)    49280       ['tnc2_initial_conv[0][0]']
#  onv1D)
#
#  activation_90 (Activation)     (None, 128, 128)     0           ['tnc2_dilated_conv_1_tanh_s0[0][
#                                                                  0]']
#
#  lambda_75 (Lambda)             (None, 128, 128)     0           ['activation_90[0][0]']
#
#  tnc2_spatial_dropout1d_1_s0_0.  (None, 128, 128)    0           ['lambda_75[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_75 (Conv1D)             (None, 128, 128)     16512       ['tnc2_spatial_dropout1d_1_s0_0.0
#                                                                  00000[0][0]']
#
#  add_90 (Add)                   (None, 128, 128)     0           ['tnc2_initial_conv[0][0]',
#                                                                   'conv1d_75[0][0]']
#
#  tnc2_dilated_conv_2_tanh_s0 (C  (None, 128, 128)    49280       ['add_90[0][0]']
#  onv1D)
#
#  activation_91 (Activation)     (None, 128, 128)     0           ['tnc2_dilated_conv_2_tanh_s0[0][
#                                                                  0]']
#
#  lambda_76 (Lambda)             (None, 128, 128)     0           ['activation_91[0][0]']
#
#  tnc2_spatial_dropout1d_2_s0_0.  (None, 128, 128)    0           ['lambda_76[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_76 (Conv1D)             (None, 128, 128)     16512       ['tnc2_spatial_dropout1d_2_s0_0.0
#                                                                  00000[0][0]']
#
#  add_91 (Add)                   (None, 128, 128)     0           ['add_90[0][0]',
#                                                                   'conv1d_76[0][0]']
#
#  tnc2_dilated_conv_4_tanh_s0 (C  (None, 128, 128)    49280       ['add_91[0][0]']
#  onv1D)
#
#  activation_92 (Activation)     (None, 128, 128)     0           ['tnc2_dilated_conv_4_tanh_s0[0][
#                                                                  0]']
#
#  lambda_77 (Lambda)             (None, 128, 128)     0           ['activation_92[0][0]']
#
#  tnc2_spatial_dropout1d_4_s0_0.  (None, 128, 128)    0           ['lambda_77[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_77 (Conv1D)             (None, 128, 128)     16512       ['tnc2_spatial_dropout1d_4_s0_0.0
#                                                                  00000[0][0]']
#
#  add_92 (Add)                   (None, 128, 128)     0           ['add_91[0][0]',
#                                                                   'conv1d_77[0][0]']
#
#  tnc2_dilated_conv_8_tanh_s0 (C  (None, 128, 128)    49280       ['add_92[0][0]']
#  onv1D)
#
#  activation_93 (Activation)     (None, 128, 128)     0           ['tnc2_dilated_conv_8_tanh_s0[0][
#                                                                  0]']
#
#  lambda_78 (Lambda)             (None, 128, 128)     0           ['activation_93[0][0]']
#
#  tnc2_spatial_dropout1d_8_s0_0.  (None, 128, 128)    0           ['lambda_78[0][0]']
#  000000 (SpatialDropout1D)
#
#  conv1d_78 (Conv1D)             (None, 128, 128)     16512       ['tnc2_spatial_dropout1d_8_s0_0.0
#                                                                  00000[0][0]']
#
#  add_93 (Add)                   (None, 128, 128)     0           ['add_92[0][0]',
#                                                                   'conv1d_78[0][0]']
#
#  tnc2_dilated_conv_16_tanh_s0 (  (None, 128, 128)    49280       ['add_93[0][0]']
#  Conv1D)
#
#  activation_94 (Activation)     (None, 128, 128)     0           ['tnc2_dilated_conv_16_tanh_s0[0]
#                                                                  [0]']
#
#  lambda_79 (Lambda)             (None, 128, 128)     0           ['activation_94[0][0]']
#
#  tnc2_spatial_dropout1d_16_s0_0  (None, 128, 128)    0           ['lambda_79[0][0]']
#  .000000 (SpatialDropout1D)
#
#  conv1d_79 (Conv1D)             (None, 128, 128)     16512       ['tnc2_spatial_dropout1d_16_s0_0.
#                                                                  000000[0][0]']
#
#  add_95 (Add)                   (None, 128, 128)     0           ['conv1d_75[0][0]',
#                                                                   'conv1d_76[0][0]',
#                                                                   'conv1d_77[0][0]',
#                                                                   'conv1d_78[0][0]',
#                                                                   'conv1d_79[0][0]']
#
#  activation_95 (Activation)     (None, 128, 128)     0           ['add_95[0][0]']
#
#  global_max_pooling1d_7 (Global  (None, 128)         0           ['activation_95[0][0]']
#  MaxPooling1D)
#
#  dense_14 (Dense)               (None, 128)          16512       ['global_max_pooling1d_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 128)          0           ['dense_14[0][0]']
#
#  dense_15 (Dense)               (None, 20)           2580        ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 694,420
# Trainable params: 694,420
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Average scores 
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.03460532799363136 - Accuracy: 99.12734627723694%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.027990803122520447 - Accuracy: 99.28970336914062%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.026369981467723846 - Accuracy: 99.22881722450256%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.030791712924838066 - Accuracy: 99.21867251396179%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.04186524450778961 - Accuracy: 98.99543523788452%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 99.17199492454529 (+- 0.10240085323417698)
# > Loss: 0.03232461400330067
# ------------------------------------------------------------------------
